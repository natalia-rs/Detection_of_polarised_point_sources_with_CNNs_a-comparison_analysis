# %%
import numpy as np
import pandas as pd
import healpy as hp
import matplotlib.pyplot as plt
from skimage.feature import peak_local_max
from skimage.measure import label
from scipy.ndimage import center_of_mass
import matplotlib.colors as colors
from matplotlib.colors import LogNorm
import astropy.coordinates as coord
from astropy import units as u
from astropy.coordinates import Angle

# %% [markdown]
# #### **Select the 20 brightest objects in the Observation map**

# %%
# %store -r table_PS_obs

# %%
table_PS_obs_sorted = table_PS_obs.sort_values(by='S(Jy)', ascending=False)

top_20 = table_PS_obs_sorted.head(20)

table_PS_obs_brightest = top_20.copy()

# %%
table_PS_obs_brightest
# Out:
#     indices      lon(°)     lat(°)     S(Jy)
# 0   5787504  167.343750   4.593056  9.692273
# 1   2769064  194.809570  34.048594  9.488377
# 2   1760418  250.090618  46.079678  9.044970
# 3   6983054  124.980469  -6.316817  8.951799
# 4   2129821  171.342773  41.411189  8.940343
# 5   8785731  163.388672 -23.358583  8.936742
# 6   9405489  274.350586 -29.656014  8.573457
# 7   7129765   59.501953  -7.669783  8.248748
# 8   1604158   31.992188  48.141208  8.034181
# 9    392842  249.988713  69.654664  7.935913
# 10  9738183  354.990234 -33.197454  7.865232
# 11  7981176   10.546875 -15.597644  7.847813
# 12  9717061  298.608398 -32.974849  7.842380
# 13  9151191  243.940430 -27.028078  7.715163
# 14  8208714  209.047852 -17.739364  7.679785
# 15  6744948   77.695312  -4.144128  7.675251
# 16  7031184   35.156250  -6.767375  7.637537
# 17  7949139   74.794922 -15.288050  7.595070
# 18  6114378   96.503906   1.604193  7.480286
# 19  7323748  188.833008  -9.442778  7.349763

# %%
# %store -r lon
# %store -r lat
# %store -r xsize
# %store -r reso

# %%
lon_PS_obs = table_PS_obs_brightest['lon(°)']
lat_PS_obs = table_PS_obs_brightest['lat(°)']

# %%
lon_rad = np.radians(lon)
lat_rad = np.radians(lat)
lon_PS_obs_rad = np.radians(lon_PS_obs.values)
lat_PS_obs_rad = np.radians(lat_PS_obs.values)

# %%
#reso is in arcmin
def convert_lonlat_to_patch_position(lon_PS, lat_PS, lon_PS_rad, lat_PS_rad, lon = lon, lat = lat, xsize = xsize, reso = reso):
    patch_positions = []

    for lon_PS_rad, lat_PS_rad, lon_PS, lat_PS in zip(lon_PS_rad, lat_PS_rad, lon_PS, lat_PS):
        
        patch_index = np.argmin(coord.angular_separation(lon_PS_rad, lat_PS_rad, lon_rad, lat_rad))

        patch_lon, patch_lat = lon[patch_index], lat[patch_index]

        proj = hp.projector.GnomonicProj(ysize=xsize, xsize=xsize, rot=(patch_lon, patch_lat, 0), reso=reso)
        x, y = proj.ang2xy(lon_PS, lat_PS, lonlat=True)
        i,j = proj.xy2ij(x = x, y = y)
        

        patch_positions.append((patch_index, i, j))

    return patch_positions

# %%
brightest20_obs = convert_lonlat_to_patch_position(lon_PS_obs, lat_PS_obs, lon_PS_obs_rad, lat_PS_obs_rad)

# %%
brightest20_obs
# Out:
# [(1439, 17, 32),
#  (700, 29, 5),
#  (480, 50, 42),
#  (1727, 16, 18),
#  (537, 31, 19),
#  (2221, 33, 16),
#  (2426, 48, 29),
#  (1809, 55, 40),
#  (370, 23, 8),
#  (101, 22, 24),
#  (2528, 49, 10),
#  (1992, 42, 12),
#  (2515, 53, 10),
#  (2332, 31, 44),
#  (2045, 5, 16),
#  (1714, 54, 26),
#  (1702, 8, 15),
#  (2009, 48, 3),
#  (1519, 28, 12),
#  (1844, 24, 5)]

# %% [markdown]
# #### **Point source only E map**

# %%
# %store -r E_obs

# %%
ps_map_E_obs_patches = [hp.gnomview(E_obs, rot=[lon[i], lat[i]], xsize = xsize, reso = reso, return_projected_map = True, no_plot = True) for i in range(len(lon))]

# %%
# %store ps_map_E_obs_patches
# Out:
# Stored 'ps_map_E_obs_patches' (list)

# %% [markdown]
# #### **Patch comparison**

# %%
# Store the prediction
# %store -r prediction_EB_64pix_9epoch_10batch

# %%
# Store the observation
# %store -r map_cut_data_EB_obs

# %%
patch_numbers = [item[0] for item in brightest20_obs]
peak_patch_x = [item[2] for item in brightest20_obs]
peak_patch_y = [item[1] for item in brightest20_obs]

# %%
fig, axes = plt.subplots(20, 3, figsize=(18, 60), dpi=200)

for i, (patch_number, peak_x, peak_y) in enumerate(zip(patch_numbers[:20], peak_patch_x[:20], peak_patch_y[:20])):
    
    def test(observation, prediction, n=patch_number, peak_distance_tol=5): 
        observation = np.squeeze(observation[n])
        observation = observation[:,:,0] # we are represeting E map
        prediction = np.squeeze(prediction[n])
        prediction_peaks = peak_local_max(prediction[:, :], threshold_abs = 0.3, min_distance=peak_distance_tol, exclude_border=False)
        return prediction_peaks, observation, prediction  
    
        
    # S_new_obs plot
    ax1 = axes[i, 0]    
    sc1 = ax1.imshow(ps_map_E_obs_patches[patch_number])
    cbar1 = fig.colorbar(sc1, ax=ax1)
    ax1.set_title(f"Smoothed Q map of the PS ({i+1})")

        
    # Observation
    ax2 = axes[i, 1]  
    image_data2 = test(map_cut_data_EB_obs, prediction_EB_64pix_9epoch_10batch)[1]
    sc2 = ax2.imshow(image_data2)
    ax2.scatter(x=peak_x, y=peak_y, color='magenta', s=20)
    cbar2 = fig.colorbar(sc2, ax=ax2)
    ax2.set_title(f"Observation Q map ({i+1})")

    
    # Prediction
    ax3 = axes[i, 2]  
    image_data3 = test(map_cut_data_EB_obs, prediction_EB_64pix_9epoch_10batch)[2]
    sc3 = ax3.imshow(image_data3)
    ax3.scatter(x=test(map_cut_data_EB_obs, prediction_EB_64pix_9epoch_10batch)[0][:, 1],
                y=test(map_cut_data_EB_obs, prediction_EB_64pix_9epoch_10batch)[0][:, 0], c='red', marker='x')
    cbar3 = fig.colorbar(sc3, ax=ax3)
    ax3.set_title(f"Prediction ({i+1})")



plt.tight_layout()  
plt.savefig('Patches_EB_0.3threshold.pdf', format='pdf')
plt.show()

# %%
fig, axes = plt.subplots(10, 3, figsize=(18, 30), dpi=200)

for i in np.arange(0,10):
    
    def test(observation, prediction, n=i, peak_distance_tol=5): 
        observation = np.squeeze(observation[n])
        observation = observation[:,:,0]
        prediction = np.squeeze(prediction[n])
        prediction_peaks = peak_local_max(prediction[:, :], threshold_abs = 0.3, min_distance=peak_distance_tol, exclude_border=False)
        return prediction_peaks, observation, prediction  
    
        
    # S_new_obs plot
    ax1 = axes[i, 0]    
    sc1 = ax1.imshow(ps_map_Q_obs_patches[i])
    cbar1 = fig.colorbar(sc1, ax=ax1)
    ax1.set_title(f"Smoothed Q map of the PS ({i+1})")

        
    # Observation
    ax2 = axes[i, 1]  
    image_data2 = test(map_cut_data_QU_obs, prediction_QU_64pix_9epoch_10batch)[1]
    sc2 = ax2.imshow(image_data2)
    cbar2 = fig.colorbar(sc2, ax=ax2)
    ax2.set_title(f"Observation Q map ({i+1})")

    
    # Prediction
    ax3 = axes[i, 2]  
    image_data3 = test(map_cut_data_QU_obs, prediction_QU_64pix_9epoch_10batch)[2]
    sc3 = ax3.imshow(image_data3)
    ax3.scatter(x=test(map_cut_data_QU_obs, prediction_QU_64pix_9epoch_10batch)[0][:, 1],
                y=test(map_cut_data_QU_obs, prediction_QU_64pix_9epoch_10batch)[0][:, 0], c='red', marker='x')
    cbar3 = fig.colorbar(sc3, ax=ax3)
    ax3.set_title(f"Prediction ({i+1})")



plt.tight_layout()  
plt.show()
