# %%
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

# %%
# For 0.3 threshold
# %store -r table_detections_EB
# %store -r table_spurious_EB

# %%
# %store -r table_detections_P
# %store -r table_spurious_P

# %%
# %store -r table_PS_obs

# %%
# %store -r table_detections_E
# %store -r table_spurious_E

# %%
def sky_ps_map(table_detections, table_spurious, nside=1024, filename='Sky_ps.jpg', title='Sky Point Sources for EB'):
    lon1 = np.array(table_detections['lon(°)'])
    lat1 = np.array(table_detections['lat(°)'])
    indices1 = hp.ang2pix(nside, lon1, lat1, lonlat=True)
    
    if len(table_spurious) > 0:
        lon2 = np.array(table_spurious['lon(°)'])
        lat2 = np.array(table_spurious['lat(°)'])
        indices2 = hp.ang2pix(nside, lon2, lat2, lonlat=True)
    else:
        lon2 = lat2 = []
        indices2 = []

    skymap = np.zeros(hp.nside2npix(nside))
    skymap[indices1] = 1
    skymap[indices2] = 1

    fig = plt.figure(figsize=(10, 6))  

    hp.mollview(skymap, cmap='gray', title=title, cbar=False)
    hp.projscatter(lon1, lat1, lonlat=True, s=1, c='red', marker='o', label='Detections')
    #hp.projscatter(lon2, lat2, lonlat=True, s=1, c='cyan', marker='o', label='Spurious')
    plt.legend()

    plt.savefig(filename, dpi=200)
    plt.show()

    return fig, skymap

# %%
fig = sky_ps_map(table_detections_E, table_spurious_E, filename='Sky_PS_E_03.jpg', title='Sky Point Sources for E')

# %%
fig = sky_ps_map(table_detections_P, table_spurious_P, filename='Sky_PS_P_03.jpg', title='Sky Point Sources for P')

# %%
fig = sky_ps_map(table_detections_EB, table_spurious_EB, filename='Sky_PS_EB_03.jpg', title='Sky Point Sources for EB')

# %%
# %store -r table_detections_P_03_foregrounds
# %store -r table_spurious_P_03_foregrounds

# %%
# %store -r table_PS_pred_P_foreg_03

# %%
fig2 = sky_ps_map(table_PS_pred_P_foreg_01, table_PS_pred_P_foreg_03, filename='prueba.jpg', title='Sky Point Sources for P with foregrounds')

# %%
fig2 = sky_ps_map(table_detections_P_03_foregrounds, table_spurious_P_03_foregrounds, filename='Sky_PS_P_03_foregrounds.jpg', title='Sky Point Sources for P with foregrounds')

# %%
# %store -r table_detections_EB_03_foregrounds
# %store -r table_spurious_EB_03_foregrounds

# %%
fig3 = sky_ps_map(table_detections_EB_03_foregrounds, table_spurious_EB_03_foregrounds, filename='Sky_PS_EB_03_foregrounds.jpg', title='Sky Point Sources for EB with foregrounds')

# %%
# %store -r table_detections_QU_03_foregrounds
# %store -r table_spurious_QU_03_foregrounds

# %%
fig4 = sky_ps_map(table_detections_QU_03_foregrounds, table_spurious_QU_03_foregrounds, filename='Sky_PS_QU_03_foregrounds.jpg', title='Sky Point Sources for QU with foregrounds')
