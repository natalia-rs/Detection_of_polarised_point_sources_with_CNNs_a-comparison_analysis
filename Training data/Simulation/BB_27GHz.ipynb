# %% [markdown]
# #### **Comparison of spectra for BB: theoretical, simulated, point sources, white noise**

# %%
import pandas as pd
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##### **1. Theoretical and simulated spectra**

# %%
# %store -r data

# %%
# We check that the data file columns give Dℓ = ℓ(ℓ+1)Cℓ / 2π in units of μK
data.BB = data.BB/((10**6)**2) # convert to Kelvin
prefactor_Dl = data.L * (data.L + 1) / (2 * np.pi)
cl_BB_teorico = data.BB/prefactor_Dl
data['cl_BB_teorico'] = cl_BB_teorico #add column

# %%
# Because we have no data for L=0,1 we fill it with zeros
null_row_0 = pd.DataFrame({'L':0, 'TT':0,'TE':0,'EE':0,'BB':0,'PP':0, 'cl_BB_teorico':0}, index=[0])
null_row_1 = pd.DataFrame({'L':0, 'TT':0,'TE':0,'EE':0,'BB':0,'PP':0, 'cl_BB_teorico':0}, index=[1])
data = pd.concat([null_row_0,data.loc[:]]).reset_index(drop=True)
data = pd.concat([null_row_1,data.loc[:]]).reset_index(drop=True)

# %%
# %store -r nside
# %store -r fwhm

# %%
# Simulated power spectrum
lmax = data.L.iloc[-1]
BB_simulated = hp.synfast(data.cl_BB_teorico, nside = nside, lmax = lmax, fwhm = fwhm) # creates a map from Cl's
cl_BB_simulated = hp.anafast(BB_simulated) # simulated power spectrum from the input simulated BB map

# %%
# %store cl_BB_simulated
# Out:
# Stored 'cl_BB_simulated' (ndarray)

# %% [markdown]
# ##### **2. Point source spectra**

# %%
# %store -r BB_cl

# %% [markdown]
# The power spectrum of the point sources comes from the smoothed map

# %% [markdown]
# ##### **3. White noise spectra**

# %%
# %store -r cl_noise_BB_simulated

# %% [markdown]
# ##### **4. Plot**

# %%
ell = np.arange(2499) 

plt.figure(figsize=(9, 6))  
# Plot the data
plt.plot(ell, BB_cl[:2499] * ell * (ell + 1) / (2 * np.pi), label='Point sources', linestyle='-', linewidth=2, color = 'deeppink')
plt.plot(ell, cl_BB_simulated[:2499] * ell * (ell + 1) / (2 * np.pi), label='Simulated CMB', linestyle='-', linewidth=2, color = 'slateblue')
plt.plot(ell, cl_BB_teorico[:2499] * ell * (ell + 1) / (2 * np.pi), label='Theoretical CMB', linestyle='-', linewidth=2, c = 'midnightblue')
plt.plot(ell, cl_noise_BB_simulated[:2499] * ell * (ell + 1) / (2 * np.pi), label='Instrumental noise', linestyle='-', linewidth=2, color = 'seagreen')

plt.ylim([10**-17,10**-8])
plt.xlim(10, ell.max())

plt.xlabel('Multipole Moment ($\ell$)', fontsize=14)
plt.ylabel(r'$\ell(\ell+1)C_\ell/2\pi$' + ' [$K^2$]', fontsize=14)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(fontsize=12)

plt.xscale('log')
plt.yscale('log')

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.savefig("BB_plot.jpg", dpi = 150)

plt.show()
